# %%
k = GF((2, 4),'c')
k
# Out:
# Finite Field in c of size 2^4

# %%
K.<a> = GF(2**4, name='a', modulus=x^4 - x^3 +1 )

# %%
K
# Out:
# Finite Field in a of size 2^4

# %%
a
# Out:
# a

# %%
a**45
# Out:
# 1

# %%
a**15
# Out:
# 1
