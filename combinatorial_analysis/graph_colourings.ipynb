# %%
from sage.graphs.graph_coloring import chromatic_number
G = Graph({
    1 : [2, 6, 5],
    2 : [3, 6, 5],
    3 : [4, 5, 6],
    4 : [5, 6]
})
G.chromatic_number()
# Out:
# 3

# %%
G1 = Graph({
    1 : [2, 4, 5, 6],
    2 : [4, 5, 6],
    3 : [4, 5, 6],
    4 : [5]
})
G1.chromatic_number()
# Out:
# 4

# %%
L = list(graphs(3))
for i in range(4):
    print(L[i])
# Out:
# Graph on 3 vertices
# Graph on 3 vertices
# Graph on 3 vertices
# Graph on 3 vertices

# %%
G2 = Graph({
    1: [2, 10],
    2: [1, 3, 10, 11, 12],
    3: [5, 10, 11],
    4: [5, 10],
    5: [6, 11],
    6: [7],
    7: [8],
    8: [9, 12],
    9: [10],
    10: [11, 12],
    11: [12]
})
# Out:
# Graphics object consisting of 34 graphics primitives

# %%
G3 = graphs.FruchtGraph()
G3
# Out:
# Frucht graph: Graph on 12 vertices

# %%
G3.automorphism_group()
# Out:
# Permutation Group with generators [()]

# %%
G4 = Graph({
    1: [2, 3, 6],
    2: [3, 4, 6],
    3: [4, 6],
    4: [5],
    5: [6]
})
G4.chromatic_number()
# Out:
# 4
