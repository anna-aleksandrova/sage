# %%
def equal_degree_sequences(n):
    needed_set = list(graphs(n))
    classes = {}
    for i in range(len(needed_set)):
        for j in range(i + 1, len(needed_set)):
            temp1 = tuple(needed_set[i].degree_sequence())
            temp2 = tuple(needed_set[j].degree_sequence())
            if temp1 == temp2 and (needed_set[i].chromatic_number() != needed_set[j].chromatic_number()):
                if temp1 not in classes:
                    classes[temp1] = {(i, needed_set[i].chromatic_number()), (j, needed_set[j].chromatic_number())}
                else:
                    classes[temp1].add((j, needed_set[j].chromatic_number()))
    return classes, needed_set
equal_degree_sequences(5)[0]
# Out:
# {(3, 2, 2, 2, 1): {(13, 2), (21, 3)},
#  (3, 3, 2, 2, 2): {(17, 2), (24, 3)},
#  (2, 2, 2, 1, 1): {(19, 2), (20, 3)}}

# %%
print(needed_set[13].chromatic_number())
print(needed_set[21].chromatic_number())
# Out:
# 2
# 3

# %%
needed_set[13].plot()
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
needed_set[21].plot()
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
print(needed_set[17].chromatic_number())
print(needed_set[24].chromatic_number())
# Out:
# 2
# 3

# %%
needed_set[17].plot()
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
needed_set[24].plot()
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
print(needed_set[19].chromatic_number())
print(needed_set[20].chromatic_number())
# Out:
# 2
# 3

# %%
needed_set[19].plot()
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
needed_set[20].plot()
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
classes, needed_set = equal_degree_sequences(6)
classes
# Out:
# {(3, 2, 2, 2, 1, 0): {(18, 2), (40, 3)},
#  (3, 2, 2, 1, 1, 1): {(19, 2), (41, 3)},
#  (4, 2, 2, 2, 1, 1): {(23, 2), (42, 3)},
#  (3, 3, 2, 2, 2, 0): {(27, 2), (47, 3)},
#  (3, 3, 2, 2, 1, 1): {(28, 2), (60, 3), (61, 3), (62, 3)},
#  (4, 3, 2, 2, 2, 1): {(29, 2), (51, 3), (64, 3), (65, 3)},
#  (4, 4, 2, 2, 2, 2): {(33, 2), (75, 3)},
#  (2, 2, 2, 1, 1, 0): {(36, 2), (38, 3)},
#  (3, 2, 2, 2, 2, 1): {(48, 3), (58, 2), (59, 3)},
#  (2, 2, 2, 2, 1, 1): {(55, 2), (57, 3)},
#  (3, 3, 2, 2, 2, 2): {(71, 3), (89, 2), (91, 3), (118, 3)},
#  (4, 3, 3, 3, 2, 1): {(77, 3), (121, 4)},
#  (4, 4, 3, 3, 2, 2): {(81, 3), (127, 4)},
#  (3, 3, 3, 2, 2, 1): {(83, 2), (90, 3), (93, 3), (117, 3)},
#  (2, 2, 2, 2, 2, 2): {(88, 2), (116, 3)},
#  (3, 3, 3, 3, 1, 1): {(92, 3), (119, 4)},
#  (5, 3, 3, 3, 2, 2): {(97, 3), (122, 4)},
#  (3, 3, 3, 3, 2, 2): {(98, 2), (123, 3), (131, 3), (132, 3)},
#  (5, 4, 3, 3, 3, 2): {(102, 3), (128, 4)},
#  (4, 4, 3, 3, 3, 1): {(103, 3), (125, 4)},
#  (3, 3, 3, 3, 3, 3): {(111, 2), (135, 3)},
#  (4, 4, 4, 3, 3, 2): {(113, 3), (140, 4)},
#  (5, 4, 4, 3, 3, 3): {(114, 3), (138, 4)},
#  (4, 4, 4, 4, 3, 3): {(148, 3), (150, 4)}}

# %%
needed_set[148].plot(layout='planar')
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
needed_set[150].plot()
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
needed_set[113].plot(layout='planar')
# Out:
# Graphics object consisting of 17 graphics primitives

# %%
needed_set[140].plot(layout='planar')
# Out:
# Graphics object consisting of 17 graphics primitives

# %%
print(needed_set[60].chromatic_number())
print(needed_set[62].chromatic_number())
# Out:
# 3
# 3

# %%
G1 = needed_set[148]
G2 = needed_set[150]

# %%
def present(cycles, cycle):
    for i in range(3):
        temp = [cycle[(i)%3], cycle[(i+1)%3], cycle[(i+2)%3]]
        if tuple(temp) in cycles:
            return True
    return False

def cycles_of_length(G):
    cycles = []
    for i1 in range(6):
        for i2 in range(6):
            for i3 in range(6):
                if G.has_edge(i1, i2) and G.has_edge(i2, i3) and G.has_edge(i3, i1):
                    cycles.append((i1, i2, i3))
    return cycles

cycles_of_length(G1)
# Out:
# [(0, 2, 4),
#  (0, 2, 5),
#  (0, 3, 5),
#  (0, 4, 2),
#  (0, 5, 2),
#  (0, 5, 3),
#  (1, 2, 4),
#  (1, 2, 5),
#  (1, 3, 5),
#  (1, 4, 2),
#  (1, 5, 2),
#  (1, 5, 3),
#  (2, 0, 4),
#  (2, 0, 5),
#  (2, 1, 4),
#  (2, 1, 5),
#  (2, 4, 0),
#  (2, 4, 1),
#  (2, 5, 0),
#  (2, 5, 1),
#  (3, 0, 5),
#  (3, 1, 5),
#  (3, 5, 0),
#  (3, 5, 1),
#  (4, 0, 2),
#  (4, 1, 2),
#  (4, 2, 0),
#  (4, 2, 1),
#  (5, 0, 2),
#  (5, 0, 3),
#  (5, 1, 2),
#  (5, 1, 3),
#  (5, 2, 0),
#  (5, 2, 1),
#  (5, 3, 0),
#  (5, 3, 1)]

# %%
i1 = 0
i2 = 3
i3 = 1
i4 = 4
G.has_edge(i1, i2) and G.has_edge(i2, i3) and G.has_edge(i3, i4) and G.has_edge(i4, i1)
# Out:
# True
