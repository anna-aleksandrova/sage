# %%
G = CyclicPermutationGroup(4)
G.gens()
# Out:
# ((1,2,3,4),)

# %%
g = graphs.CycleGraph(4)
G = g.automorphism_group()
G.structure_description()
# Out:
# 'D4'

# %%
g = graphs.CycleGraph(4)
g.add_edge([0, 2])
G = g.automorphism_group()
x = G.stabilizer(1)
y = G.order()
y / x.order()
# Out:
# 2

# %%
g
# Out:
# Cycle graph: Graph on 4 vertices

# %%
g = graphs.CubeGraph(3)
G = g.automorphism_group()
G.structure_description()
g.plot(layout="spring")
G.gens()
# Out:
# (('010','100')('011','101'),
#  ('001','010')('101','110'),
#  ('000','001')('010','011')('100','101')('110','111'))

# %%
g
# Out:
# 3-Cube: Graph on 8 vertices

# %%
G = DihedralGroup(4)
G.gens()
G.cayley_graph()
# Out:
# Digraph on 8 vertices

# %%
g = graphs.PetersenGraph()
G = g.automorphism_group()
G.structure_description()
# Out:
# 'S5'

# %%
G = Graph()
G.add_vertex(1)
G.add_vertex(2)
G.add_vertex(3)
G.add_vertex(4)
G_group = G.automorphism_group()
G_group.structure_description()
# Out:
# 'S4'

# %%
plot(G)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
G = graphs.FruchtGraph()
H = G.automorphism_group()
H.list()
# Out:
# [()]

# %%
G
# Out:
# Frucht graph: Graph on 12 vertices
