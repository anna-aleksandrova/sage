# %%
k = GF(5)

# %%
type(k)
# Out:
# <class 'sage.rings.finite_rings.finite_field_prime_modn.FiniteField_prime_modn_with_category'>

# %%
k = GF(3^2, 'alpha')

# %%
for i, x in enumerate(k): print(f"{i}, {x}")
# Out:
# 0, 0
# 1, alpha
# 2, alpha + 1
# 3, 2*alpha + 1
# 4, 2
# 5, 2*alpha
# 6, 2*alpha + 2
# 7, alpha + 2
# 8, 1

# %%
GF(next_prime(19^20)).is_field()
# Out:
# True

# %%
F.<a> = GF(7^15)

# %%
F
# Out:
# Finite Field in a of size 7^15

# %%
F.polynomial()
# Out:
# a^15 + 5*a^6 + 6*a^5 + 6*a^4 + 4*a^3 + a^2 + 2*a + 4

# %%
conway_polynomial(7, 15)
# Out:
# x^15 + 5*x^6 + 6*x^5 + 6*x^4 + 4*x^3 + x^2 + 2*x + 4

# %%
y = polygen(Integers(7), 'y')
P = y.parent()
p = P([4, 5, 8, 3])
p
# Out:
# 3*y^3 + y^2 + 5*y + 4

# %%
p.is_irreducible()
# Out:
# False
